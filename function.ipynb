# %% [markdown]
# # FUNCTIONS

# %% [markdown]
# 1. What is the difference between a function and a method in Python ?
# - The primary distinction between a function and a method lies in their association with objects.
#   Method is always present inside the class, while the class is not required to define the function.
# 2.  Create a Python function that accepts a string and returns the reverse of that string.
# - def reverse_string(good morning)
# - return input_string[::-1]
# - result = reverse_string("good morning")
# - print(result)
# 3.  What are the different ways to define and call a function in Python?
# -  call functions using keyword arguments, which allows to specify which parameter you are providing a value for.
# - small anonymous functions using the lambda keyword. These are often used for short, throwaway functions.
# 4. What is the purpose of the `return` statement in a Python function?
# - the return statment is used for the following functionsas follows:
# - the reyurn statment used to send and value back to the function
# - a function have multiple return statment allowing it to return multiple values based on conditions
# 5. What are iterators in Python and how do they differ from iterables?
# - An iterator is an object that represents a stream of data. It is used to iterate over an iterable.
# - The differance is :
# 1. An iterable is an object that can be iterated over and an iterator is an object that keeps track of the current position during iteration and provides the next value.
# 2. An iterable does not maintain any state about the iteration ans an iterator maintains its state, allowing it to remember where it is in the iteration process.
# 6. Explain the concept of generators in Python and how they are defined.
# - Generators in Python are a special type of iterator that allow you to create iterators in a more concise and memory-efficient way. They are defined using functions and the yield statement which allows the function to produce a series of values over time rather than computing them all at once and returning them in a list.
# A generator is defined like a regular function but uses the yield statement to return values.
# 8. What is a lambda function in Python and when is it typically used?
# - the lembda function is an anonymus function defind using function lembda. lembda function is short and simple operation and can take any number of argument and have a single experssion .
# - this function is used for :
# 1. As Arguments to Higher-Order Functions.
#
# 9. Explain the purpose and usage of the map() function in Python.
# - The map() function in Python is a built-in higher-order function that allows you to apply a specified function to each item in an iterable and return a map object.
# - map() is used to apply a transformation function to each element of an itrable .
# - map() is a key feature in functional programming paradigms, allowing for cleaner and more readable code.
#  '''
#  number = (1,2,3,4,5,6,7)
#  squares = map(lembda x: x**2, numbers )
#  '''
#  10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python.
#  - The map() function applies a specified function to each item in an iterable and returns a new iterable containing the results.
#  - The filter() function constructs an iterator from elements of an iterable for which a specified function returns True. It is used to filter out elements based on a condition.
#  - The reduce() function applies a specified function cumulatively to the items of an iterable, reducing the iterable to a single value.
#
#  > differance between them :
# 1. map(): Transforms each element in an iterable using a function.
# - filter(): Selects elements from an iterable based on a condition defined by a function.
# - reduce(): Aggregates elements in an iterable into a single value using a cumulative function.
# 2. map() and filter() return an iterator that can be converted to a list or other iterable types.
# - reduce() returns a single value.

# %% [markdown]
# # 11. Write the internal mechanism for the sum operation using reduce function on this list [47,11,42,13]

# %%
def sum_numbers('numbers')
    total_sum = 0
    for number in numbers:
        total_sum += number
    return total_sum
numbers_list = [47, 11, 42, 13]
result = sum_numbers("numbers_list")
print("The sum is:", result)
# Out:
#   File "<ipython-input-3-75f1339a439d>", line 1
#     def sum_numbers('numbers')
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# practice queations:

# %% [markdown]
# # 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(input_string):
    return input_string[::-1]
example_string = "good morning"
reversed_string = reverse_string(example_string)
print("Reversed string:", reversed_string)
# Out:
# Reversed string: gninrom doog

# %% [markdown]
# # 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# %%
def sum_of_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
            return total

numbers_list = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(numbers_list)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 2

# %% [markdown]
# # 3.  Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# %%
def square_numbers(numbers):
    squared_list = [num ** 2 for num in numbers]
    return squared_list

input_list = [1, 2, 3, 4, 5]
squared_result = square_numbers(input_list)
print("Squared numbers:", squared_result)
# Out:
# Squared numbers: [1, 4, 9, 16, 25]

# %% [markdown]
# # 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

for number in range(1, 201):
    if is_prime(number):
        print(f"{number} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %% [markdown]
# # 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

for power in powers_of_two(10):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024

# %% [markdown]
# # 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple

# %%
tuples_list = [(1, 'banana'), (2, 'apple'), (3, 'orange'), (4, 'grape')]
sorted_tuples = sorted(tuples_list, key=lambda x: x[1])
print(sorted_tuples)
# Out:
# [(2, 'apple'), (1, 'banana'), (4, 'grape'), (3, 'orange')]

# %% [markdown]
# # 9.  Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit

# %%
tuples_list = [(1, 'banana'), (2, 'apple'), (3, 'orange'), (4, 'grape')]
sorted_tuples = sorted(tuples_list, key=lambda x: x[1])
print(sorted_tuples)
# Out:
# [(2, 'apple'), (1, 'banana'), (4, 'grape'), (3, 'orange')]

# %% [markdown]
# # 10. . Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def is_not_vowel(char):
    return char.lower() not in 'aeiou'
input_string = "Hello, World!"
filtered_string = ''.join(filter(is_not_vowel, input_string))

print("Original string:", input_string)
print("String without vowels:", filtered_string)
# Out:
# Original string: Hello, World!
# String without vowels: Hll, Wrld!
